# %%
import structlog
log=structlog.get_logger()

# %%
log.info("User uploaded a file", user_id=123, filename="report.pdf")
# Out:
# 2025-08-22 19:06:55 [info     ] User uploaded a file           filename=report.pdf user_id=123

# %%
log.error("Failed to process PDF", error="File not found", user_id=123)
# Out:
# 2025-08-22 19:07:09 [error    ] Failed to process PDF          error='File not found' user_id=123

# %% [markdown]
# ## AWS Repo(ELK)
# ## ECS LOGS
# ## Cloud Watch

# %%
import structlog
